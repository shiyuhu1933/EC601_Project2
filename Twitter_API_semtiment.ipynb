# %% [markdown]
# <a href="https://colab.research.google.com/github/shiyuhu1933/EC601_Project2/blob/main/Twitter_API_semtiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy

#consumer_key ='Your API key/consumer key'
#consumer_secret = 'Your secret API key/ consumer key'
#access_token = 'Your access token'
#access_token_secret = 'Your secret access token'
#Bearer_token ='Your bearer token'

# %%
import tweepy #https://github.com/tweepy/tweepy
import json

consumer_key = 'jSIaIOgiLNYjTZXtpnZhiO2wk'
consumer_secret = '01LBXE6ojXv3vikLpu6w8KMiMYVn6zT25mZFu0WXoijONWuvJC'
access_token = "1576044567178186752-Dc3aW6fuQfr6mhi3tE2Yk5VQAVQKdG"
access_token_secret = "wIVicLJz3cKtLoLocIqyYenoxKLPLWqhjBvJZbThkWRZx"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

#Get tweets of the user by timeline
#'count' can specify the number of tweets
public_tweets = api.user_timeline(id="NickiMinaj", count=100)

#Set a number before the printing tweets
i=1

#Print tweets of the user by timeline
for tweet in public_tweets:
    print(str(i)+'. '+tweet.text+'\n')
    i=i+1
# Out:
# 1. @ThegirlJT ABSOLUTELY NOT!!!! I REBUKE IT IN JESUS NAME!!!!!
#
# 2. #QueenMix so 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥- @iamakbarvback @KatieGotBandz @MaliibuMiitch @ThegirlJT @BIABIA ❣️🎈💯
#
# 3. Wait https://t.co/bBS9y1hXCg
#
# 4. 😋 https://t.co/mtc0e38IOP
#
# 5. https://t.co/8ofmad8fM9
#
# 6. https://t.co/BscU8VdXwY
#
# 7. 👀
#
# 8. @ThegirlJT Oh look who it is. The lady who made fun of Pastor Maraj 🥱🤨
#
# 9. Ok now let’s go
#
# 10. * Invisible
#
# 11. My name is: 🥴 good morning my son 🫡 you are one of my most trusted soldiers. Today I’m crowning you with an invinci… https://t.co/idHmSPlirL
#
# 12. Nicki dis nicki dat nicki what????!! #MadDem ☺️👅
#
# 13. @BadGirlChunLi Ntm
#
# 14. RT @onikascrown: Which Super Freaky Girl mood y’all in ? https://t.co/nPDw4Vgcw7
#
# 15. Onika Tanya Maraj = the best btch in the whole wide world. Wow.
#
# 16. Ugh y’all what time is it? I gotta finish this b4 I fuck wit yall.
#
# ...
